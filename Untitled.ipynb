# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib as plt
import dask.dataframe as dd

# %%
column_names = ['Code', 'Column2', 'Bid P', 'Ask P', 'Trade P',
                'Bid V', 'Ask V', 'Trade V', 'Update Type', 'Column10',
                'Date', 'Time', 'Column13', 'Column14', 'Condition Codes', 'Column16']  
df = dd.read_csv('scandi.csv', names=column_names, header=None, dtype={'Column16': 'object'})
summary_stats = df.describe()
summary_stats_computed = summary_stats.compute()
print(summary_stats_computed)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/dask/backends.py:140, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     139 try:
# --> 140     return func(*args, **kwargs)
#     141 except Exception as e:
#
# File /opt/conda/lib/python3.11/site-packages/dask/dataframe/io/csv.py:771, in make_reader.<locals>.read(urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     758 def read(
#     759     urlpath,
#     760     blocksize="default",
#    (...)
#     769     **kwargs,
#     770 ):
# --> 771     return read_pandas(
#     772         reader,
#     773         urlpath,
#     774         blocksize=blocksize,
#     775         lineterminator=lineterminator,
# ...

# %%
summary_stats = df.describe()
summary_stats_computed = summary_stats.compute()
print(summary_stats_computed)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/dask/backends.py:140, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     139 try:
# --> 140     return func(*args, **kwargs)
#     141 except Exception as e:
#
# File /opt/conda/lib/python3.11/site-packages/dask/dataframe/io/csv.py:771, in make_reader.<locals>.read(urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     758 def read(
#     759     urlpath,
#     760     blocksize="default",
#    (...)
#     769     **kwargs,
#     770 ):
# --> 771     return read_pandas(
#     772         reader,
#     773         urlpath,
#     774         blocksize=blocksize,
#     775         lineterminator=lineterminator,
# ...
